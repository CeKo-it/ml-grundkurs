# %% [markdown]
# <img src="..."
#      style="display:block;margin:auto;width:10%"/>
# <br>
#
# <div style="text-align:center; font-size:200%;">
#  <b>Klassifizierer für Lucky 7</b>
# </div>
# <br/>
# <div style="text-align:center;">Dr. Matthias Hölzl</div>
# <br/>
# <!-- 08 Klassifizierer für Lucky 7.ipynb -->
# <!-- python_courses/slides/module_700_ml_basics/topic_170_lucky7_classifiers.py -->

# %%
import pickle

import matplotlib.pyplot as plt  # noqa
import numpy as np  # noqa

# %%
try:
    from python_courses.envconfig import EnvConfig
except ModuleNotFoundError:
    from envconfig import EnvConfig  # noqa

# %%
config = EnvConfig()

# %%
with open(config.processed_mnist_pkl_path, "rb") as file:
    mnist_data = pickle.load(file)

# %%
x_train = mnist_data["x_train"]
x_test = mnist_data["x_test"]
y_train = mnist_data["y_train"]
y_test = mnist_data["y_test"]

# %%
lucky7_train = y_train == 7
lucky7_test = y_test == 7

# %%
from sklearn.metrics import classification_report
from sklearn.linear_model import SGDClassifier

# %% [markdown]
# ## Drucken von Konfusionsmatrizen

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, classification_report

# %%
def plot_confusion_matrices(clf, x_train, x_test, y_train, y_test, normalize=None):
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 9))
    fig.tight_layout()
    fig.suptitle(f"Confusion Matrices (Normalize={normalize})")
    ConfusionMatrixDisplay.from_predictions(
        y_test,
        clf.predict(x_test),
        normalize=normalize,
        ax=ax1,
        colorbar=False,
        values_format=".3f" if normalize else None,
    )
    ax1.set_title("Test Data")
    ConfusionMatrixDisplay.from_predictions(
        y_train,
        clf.predict(x_train),
        normalize=normalize,
        ax=ax2,
        colorbar=False,
        values_format=".3f" if normalize else None,
    )
    ax2.set_title("Training Data")
    plt.show()

# %% [markdown]
# ## Klassifikation mit Linearem Modell

# %%
sgd_clf = SGDClassifier()

# %%
sgd_clf.fit(x_train, lucky7_train)
# Out:
# SGDClassifier()

# %%
sgd_pred = sgd_clf.predict(x_test)

# %%
print(classification_report(lucky7_test, sgd_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.98      0.99      0.99      8972
#         True       0.95      0.87      0.91      1028
#
#     accuracy                           0.98     10000
#    macro avg       0.97      0.93      0.95     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
print(classification_report(lucky7_train, sgd_clf.predict(x_train)))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      0.99     53735
#         True       0.97      0.87      0.92      6265
#
#     accuracy                           0.98     60000
#    macro avg       0.98      0.93      0.95     60000
# weighted avg       0.98      0.98      0.98     60000

# %%
plot_confusion_matrices(sgd_clf, x_train, x_test, lucky7_train, lucky7_test)

# %% [markdown]
# ## Klassifikation mit Entscheidungsbäumen

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
dt_clf = DecisionTreeClassifier(max_depth=2)

# %%
dt_clf.fit(x_train, lucky7_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
dt_pred = dt_clf.predict(x_test)

# %%
fig, ax = plt.subplots(figsize=(8, 4), dpi=200)
fig.tight_layout()
plot_tree(dt_clf, ax=ax)
plt.show()

# %%
print(classification_report(lucky7_test, dt_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.92      1.00      0.96      8972
#         True       0.94      0.28      0.43      1028
#
#     accuracy                           0.92     10000
#    macro avg       0.93      0.64      0.70     10000
# weighted avg       0.93      0.92      0.91     10000

# %%
print(classification_report(lucky7_train, dt_clf.predict(x_train)))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.92      1.00      0.96     53735
#         True       0.93      0.29      0.44      6265
#
#     accuracy                           0.92     60000
#    macro avg       0.93      0.64      0.70     60000
# weighted avg       0.92      0.92      0.90     60000

# %%
plot_confusion_matrices(dt_clf, x_train, x_test, lucky7_train, lucky7_test)

# %%
plot_confusion_matrices(
    dt_clf, x_train, x_test, lucky7_train, lucky7_test, normalize="true"
)

# %%
dt_clf2 = DecisionTreeClassifier()

# %%
dt_clf2.fit(x_train, lucky7_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_pred2 = dt_clf2.predict(x_test)

# %%
print(classification_report(lucky7_test, dt_pred2))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.99      0.99      0.99      8972
#         True       0.89      0.90      0.89      1028
#
#     accuracy                           0.98     10000
#    macro avg       0.94      0.94      0.94     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
print(classification_report(lucky7_train, dt_clf2.predict(x_train)))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00     53735
#         True       1.00      1.00      1.00      6265
#
#     accuracy                           1.00     60000
#    macro avg       1.00      1.00      1.00     60000
# weighted avg       1.00      1.00      1.00     60000

# %%
plot_confusion_matrices(dt_clf2, x_train, x_test, lucky7_train, lucky7_test)

# %% [markdown]
# ## Klassifikation mit Random Forests

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_clf = RandomForestClassifier(random_state=42, n_jobs=4)

# %%
rf_clf.fit(x_train, lucky7_train)
# Out:
# RandomForestClassifier(n_jobs=4, random_state=42)

# %%
rf_pred = rf_clf.predict(x_test)

# %%
print(classification_report(lucky7_test, rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      0.99      8972
#         True       0.99      0.91      0.95      1028
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.95      0.97     10000
# weighted avg       0.99      0.99      0.99     10000

# %%
print(classification_report(lucky7_train, rf_clf.predict(x_train)))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00     53735
#         True       1.00      1.00      1.00      6265
#
#     accuracy                           1.00     60000
#    macro avg       1.00      1.00      1.00     60000
# weighted avg       1.00      1.00      1.00     60000

# %%
plot_confusion_matrices(rf_clf, x_train, x_test, lucky7_train, lucky7_test)

# %% [markdown]
# ## Vorsicht bei unbalancierten Datensätzen!
#
# Die beiden Klassen in unserem Datensatz sind unterschiedlich groß.
# Das führt dazu, dass wir bei der Beurteilung unserer Qualitätsmaße vorsichtig sein
# müssen.

# %% [markdown]
# ## Mini-Workshop: Klassifizierer für Fashion-MNIST
#
# - Trainieren und evaluieren Sie folgende Klassifizierer für Sneaker
#   für den Fashion-MNIST Datensatz:
#   - `sklearn.linear_model.RidgeClassifier`
#   - `sklearn.tree.DecisionTreeClassifier`
#   - `sklearn.neighbors.KNeighborsClassifier`
#   - `sklearn.ensemble.RandomForestClassifier`
#   - `sklearn.ensemble.HistGradientBoostingClassifier`

# %%
import pickle

import matplotlib.pyplot as plt  # noqa
import numpy as np  # noqa

# %%
try:
    from python_courses.envconfig import EnvConfig
except ModuleNotFoundError:
    from envconfig import EnvConfig  # noqa

# %%
config = EnvConfig()

# %%
with open(config.processed_fashion_mnist_pkl_path, "rb") as file:
    fashion_mnist_data = pickle.load(file)

# %%
x_train = fashion_mnist_data["x_train"]
x_test = fashion_mnist_data["x_test"]
y_train = fashion_mnist_data["y_train"]
y_test = fashion_mnist_data["y_test"]

# %%
sneaker_train = y_train == 7
sneaker_test = y_test == 7

# %%
from sklearn.linear_model import RidgeClassifier
rid_clf = RidgeClassifier()
rid_clf.fit(x_train, sneaker_train)
rid_pred = rid_clf.predict(x_test)
print(classification_report(lucky7_test, rid_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.90      0.91      0.90      8972
#         True       0.12      0.11      0.11      1028
#
#     accuracy                           0.83     10000
#    macro avg       0.51      0.51      0.51     10000
# weighted avg       0.82      0.83      0.82     10000

# %%
from sklearn.tree import DecisionTreeClassifier
tr_clf = DecisionTreeClassifier(random_state=42)
tr_clf.fit(x_train, sneaker_train)
tr_pred = tr_clf.predict(x_test)
print(classification_report(lucky7_test, tr_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.90      0.90      0.90      8972
#         True       0.11      0.11      0.11      1028
#
#     accuracy                           0.82     10000
#    macro avg       0.51      0.51      0.51     10000
# weighted avg       0.82      0.82      0.82     10000

# %%
from sklearn.neighbors import KNeighborsClassifier
kn_clf = KNeighborsClassifier(random_state=42)
kn_clf.fit(x_train, sneaker_train)
kn_pred = kn_clf.predict(x_test)
print(classification_report(lucky7_test, kn_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.90      0.90      0.90      8972
#         True       0.11      0.11      0.11      1028
#
#     accuracy                           0.82     10000
#    macro avg       0.51      0.51      0.51     10000
# weighted avg       0.82      0.82      0.82     10000

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier(random_state=42)
rf_clf.fit(x_train, sneaker_train)
rf_pred = rf_clf.predict(x_test)
print(classification_report(lucky7_test, rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.90      0.90      0.90      8972
#         True       0.11      0.11      0.11      1028
#
#     accuracy                           0.82     10000
#    macro avg       0.51      0.51      0.51     10000
# weighted avg       0.82      0.82      0.82     10000

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
hgb_clf = HistGradientBoostingClassifier(random_state=42)
hgb_clf.fit(x_train, sneaker_train)
hgb_pred = hgb_clf.predict(x_test)
print(classification_report(lucky7_test, hgb_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.90      0.90      0.90      8972
#         True       0.12      0.12      0.12      1028
#
#     accuracy                           0.82     10000
#    macro avg       0.51      0.51      0.51     10000
# weighted avg       0.82      0.82      0.82     10000

# %%
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Out:
#               precision    recall  f1-score   support
#
#        False       0.90      0.90      0.90      8972
#         True       0.11      0.11      0.11      1028
#
#     accuracy                           0.82     10000
#    macro avg       0.51      0.51      0.51     10000
# weighted avg       0.82      0.82      0.82     10000
